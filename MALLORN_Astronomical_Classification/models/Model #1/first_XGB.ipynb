# %% [markdown]
# # Model 1 (Baseline XGBoost)
#
# First attempt at building a model for this competition.
#
# ### What this model does
# - Uses basic lightcurve-derived statistical features
# - Trains an XGBoost binary classifier
# - Uses Optuna to tune hyperparameters for F1
# - Tunes a custom probability threshold to maximize validation F1
# - Generates Kaggle submissions (I submitted twice using different seeds)
#
# ### Results
# - Public leaderboard F1: 0.4582
# - Public leaderboard F1: 0.4610
#
# This model did not use heavy feature engineering, and mainly focuses on extracting simple per-object + per-filter summary stats from the raw lightcurve.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from xgboost import XGBClassifier

# %%
df = pd.read_csv('data/train_log.csv')
df
# Out:
#                      object_id       Z  Z_err    EBV        SpecType  \
# 0     Dornhoth_fervain_onodrim  3.0490    NaN  0.110             AGN
# 1          Dornhoth_galadh_ylf  0.4324    NaN  0.058           SN II
# 2         Elrim_melethril_thul  0.4673    NaN  0.577             AGN
# 3           Ithil_tobas_rodwen  0.6946    NaN  0.012             AGN
# 4          Mirion_adar_Druadan  0.4161    NaN  0.058             AGN
# ...                        ...     ...    ...    ...             ...
# 3038       tinnu_gellui_tathar  0.8898    NaN  0.042             AGN
# 3039            uir_heleg_corf  0.9598    NaN  0.042             AGN
# 3040             uir_rhosc_law  0.1543    NaN  0.024           SN II
# 3041              uruk_in_pess  1.1520    NaN  0.019             AGN
# 3042           ylf_alph_mindon  0.5595    NaN  0.034  SN Ia-91T-like
#
#                                   English Translation     split  target
# 0     Trawn Folk (Dwarfs) + northern + Ents (people)   split_01       0
# 1       Trawn Folk (Dwarfs) + tree + drinking vessel   split_01       0
# 2                     Elves +  lover (fem.)  + breath  split_01       0
# 3                       moon +  roof  +  noble maiden  split_01       0
# 4               jewel, Silmaril  + father + Wild Man   split_01       0
# ...                                               ...       ...     ...
# 3038             dusk, twilight + triumphant + tathar  split_20       0
# 3039                            eternity + ice + ring  split_20       0
# 3040     eternity +  russet, red, brown + no! don't!   split_20       0
# 3041                   evil creature + year + feather  split_20       0
# 3042         drinking vessel  + swan + isolated hill   split_20       0
#
# [3043 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# object_id                 0
# Z                         0
# Z_err                  3043
# EBV                       0
# SpecType                  0
# English Translation       0
# split                     0
# target                    0
# dtype: int64

# %% [markdown]
# ## Dropping columns
#
# Before feature building, I removed columns that are not useful for this baseline model. I didn't know what to do with SpecType at the time so i removed it, a Kaggle user later pointed out in a discussion that there is a very good way to use SpecType. Z_err was also not used yet. Z_err is only null for the training values. This is also one of the reasons the model didn't perform too well.

# %%
df.drop(columns=['Z_err', 'English Translation', 'SpecType'], inplace=True)

# %% [markdown]
# ## Loading lightcurve files
#
# The dataset is stored in separate folders by `split`.
#
# Instead of re-reading CSV files every time I want an object's lightcurve, I load each split's full lightcurve file once and store it.

# %%
splits = 20
light_curve_cache = {}
idx_cache = {}

for s in df['split'].unique():
    path = f"data/{s}/train_full_lightcurves.csv"
    light_curve = pd.read_csv(path)

    groups = light_curve.groupby("object_id").indices

    light_curve_cache[s] = light_curve
    idx_cache[s] = groups

# %% [markdown]
# ## get_lightcurve(split, object_id)
#
# This function retrieves the full lightcurve rows for a single object.
#
# Inputs:
# - split: which data split folder the object belongs to
# - object_id: unique object identifier
#
# Steps:
# - Look up the row indices for that object in idx_cache
# - Use .iloc[idx] to extract the object's rows

# %%
def get_lightcurve(split, object_id):
    df = light_curve_cache[split]
    idx = idx_cache[split].get(object_id)
    return df.iloc[idx]

# %% [markdown]
# Test

# %%
x = df.iloc[3]
split = x["split"]
obj_id = x["object_id"]
lc = get_lightcurve(split, obj_id)
lc
# Out:
#                object_id  Time (MJD)      Flux  Flux_err Filter
# 267   Ithil_tobas_rodwen  62867.5631  0.462736  1.159424      y
# 268   Ithil_tobas_rodwen  62867.5631  1.250500  0.342737      z
# 269   Ithil_tobas_rodwen  62867.5631  1.298654  0.274093      i
# 270   Ithil_tobas_rodwen  62864.6990  0.752622  0.080461      g
# 271   Ithil_tobas_rodwen  62864.6990  1.028319  0.199470      i
# ...                  ...         ...       ...       ...    ...
# 1060  Ithil_tobas_rodwen  61807.8308  0.126247  0.247917      z
# 1061  Ithil_tobas_rodwen  61810.6950  0.585870  0.314342      i
# 1062  Ithil_tobas_rodwen  61799.2384  0.455831  0.175963      i
# 1063  Ithil_tobas_rodwen  61807.8308  0.598166  0.606470      y
# 1064  Ithil_tobas_rodwen  61810.6950  0.288758  0.374822      g
#
# [798 rows x 5 columns]

# %% [markdown]
# ## Creating feature columns
#
# Each object has a time series (lightcurve) with observations in up to 6 filters: u, g, r, i, z, y
#
# The majority of these features were created by tasking chat gpt with going through astronomy research papers and creating features. I am not an astronomer therefore I cannot create astronomy features with my knowledge.
#
# - `Time (MJD)`: observation time in Modified Julian Date
# - `Flux`: measured brightness (can be negative due to noise/subtraction artifacts)
# - `Flux_err`: uncertainty in the flux measurement
# - `Filter`: which band the observation belongs to
#
# The goal of feature engineering here is to compress each irregular time series into a fixed-length numeric vector so a tabular model (like XGBoost) can learn patterns that separate classes.
#
# ### 1) Global features (all filters combined)
# These are computed using all observations across all bands for a given object.
# They summarize the overall time coverage, brightness distribution, variability, uncertainty, and signal quality.
#
# ### 2) Per-filter features (computed separately per band)
# These are computed **independently for each filter band**.
# They let the model detect color-dependent behavior (for example: strong variability in `g` but not in `i`).
#
# ## Global (all-filters combined) features
#
# Below are the global feature columns and what each one represents:
#
# | Feature | Meaning | Why it helps |
# |--------|---------|--------------|
# | `total_time` | Total time span covered by the object's observations: `(max(Time) - min(Time))` after shifting to start at zero | Separates fast events vs slow events and distinguishes sparse vs long-baseline coverage |
# | `n_obs` | Total number of observations across all filters | Captures sampling density and whether an object is well-measured |
# | `median_flux` | Median flux across all observations | Robust estimate of typical brightness (less sensitive to spikes) |
# | `mean_flux` | Mean flux across all observations | Captures average brightness but is more sensitive to outliers |
# | `std_flux` | Standard deviation of flux across all observations | Measures overall variability (high = more change over time) |
# | `min_flux` | Minimum observed flux | Captures dips, fading, or negative excursions from noise |
# | `max_flux` | Maximum observed flux | Captures peak brightness or flare intensity |
# | `range_flux` | Flux range: `max_flux - min_flux` | Simple variability amplitude proxy |
# | `median_err` | Median flux uncertainty across all observations | Measures how noisy the measurements are overall |
# | `median_snr` | Median signal-to-noise ratio: `median(\|Flux\| / Flux_err)` | Typical detection strength across observations |
# | `max_snr` | Maximum signal-to-noise ratio: `max(\|Flux\| / Flux_err)` | Whether the object ever has a highly confident detection |
# | `neg_flux_frac` | Fraction of observations where `Flux < 0` | Indicates low-SNR objects or subtraction-dominated measurements |
#
# ## Per-filter (band-wise) features
#
# For each band in `filters = ["u", "g", "r", "i", "z", "y"]`, the following features are created:
#
# | Feature | Meaning | Why it helps |
# |--------|---------|--------------|
# | `n_obs_{band}` | Number of observations in this band | Some classes are observed more in specific bands; also captures missingness patterns |
# | `total_time_{band}` | Time span covered within this band | Band-dependent cadence coverage (important if data is uneven across filters) |
# | `median_flux_{band}` | Median flux in this band | Typical brightness in this band (captures spectral/color behavior) |
# | `std_flux_{band}` | Flux standard deviation in this band | Variability strength in that band |
# | `amp_{band}` | Simple amplitude proxy: `max(flux) - median(flux)` | Captures flare-like peaks or transient bursts without being too sensitive to one negative outlier |
# | `median_err_{band}` | Median uncertainty in this band | Band-specific noise level (some filters are noisier) |
# | `median_snr_{band}` | Median SNR in this band: `median(\|flux\| / err)` | Typical detection quality per filter |
# | `max_snr_{band}` | Max SNR in this band: `max(\|flux\| / err)` | Best detection strength per filter |
# | `neg_flux_frac_{band}` | Fraction of band observations with `flux < 0` | Band-specific low-SNR indicator |
#
# ## Additional summary features
#
# These features describe how much band coverage exists overall:
#
# | Feature | Meaning | Why it helps |
# |--------|---------|--------------|
# | `n_filters_present` | Count of how many filters have at least 1 observation | Objects with multi-band coverage have richer information; missing bands may correlate with class |
# | `total_obs` | Total observations summed over all filters (same as `n_obs`) | Redundant but convenient for downstream logic or sanity checks |

# %% [markdown]
# Commenting is added by chat gpt for explanations. Normally I would research all about the feature I am implementing and explain them in my own words, But I am on a time crunch for this competition, so I will let AI do the brunt work.

# %%
filters = ["u", "g", "r", "i", "z", "y"]  # creating features for each filter

# Global feature columns (computed using all observations combined)
base_cols = [
    "total_time",      # total time span covered by all observations
    "n_obs",           # total number of observations across all filters
    "median_flux",     # median flux across all observations
    "mean_flux",       # mean flux across all observations
    "std_flux",        # standard deviation of flux across all observations
    "min_flux",        # minimum flux observed
    "max_flux",        # maximum flux observed
    "range_flux",      # max_flux - min_flux, variability range proxy
    "median_err",      # median measurement uncertainty across all observations
    "median_snr",      # median |flux| / err across all observations
    "max_snr",         # maximum |flux| / err across all observations
    "neg_flux_frac"    # fraction of observations with flux < 0
]

# Initialize global features to NaN (filled later per object)
for c in base_cols:
    df[c] = np.nan

# Initialize per-filter features
for f in filters:
    df[f"n_obs_{f}"] = 0                  # number of observations in this band
    df[f"total_time_{f}"] = 0.0           # time span covered in this band
    df[f"median_flux_{f}"] = 0.0          # typical flux level in this band
    df[f"std_flux_{f}"] = 0.0             # variability in this band
    df[f"amp_{f}"] = 0.0                  # amplitude proxy in this band
    df[f"median_err_{f}"] = 0.0           # typical uncertainty in this band
    df[f"median_snr_{f}"] = 0.0           # typical SNR in this band
    df[f"max_snr_{f}"] = 0.0              # best SNR in this band
    df[f"neg_flux_frac_{f}"] = 0.0        # fraction of negative flux values in this band

# Summary features for filter coverage
df["n_filters_present"] = 0               # how many bands have >= 1 observation
df["total_obs"] = 0                       # total observations across all bands

# %% [markdown]
# ## Extracting features from the raw lightcurve (per object)
#
# This loop runs through every object in the dataframe and builds features from its lightcurve.
#
# ### Steps per object
# 1. Fetch the object's lightcurve with `get_lightcurve(split, object_id)`
# 2. Extract arrays for:
#    - Time (MJD)
#    - Flux
#    - Flux_err
# 3. Convert time into a relative scale (`t_rel = t - t.min()`)
# 4. Compute global lightcurve stats:
#    - time span
#    - total observation count
#    - flux summary stats (median/mean/std/min/max/range)
#    - error and SNR summary stats
#    - fraction of negative flux values
# 5. For each filter band (u,g,r,i,z,y):
#    - subset lightcurve rows for that band
#    - compute band-specific stats (n_obs, time span, median flux, std, amplitude, SNR, etc.)
# 6. Track how many filters are actually present (`n_filters_present`)
# 7. Track the total number of observations across all filters (`total_obs`)
#
# This produces a structured tabular feature dataset where each row corresponds to exactly one object.

# %%
for i in range(df.shape[0]):
    x = df.iloc[i]
    lc = get_lightcurve(x["split"], x["object_id"])

    # Extract arrays for all observations (all filters combined)
    t = lc["Time (MJD)"].to_numpy()
    f = lc["Flux"].to_numpy()
    e = lc["Flux_err"].to_numpy()

    # Shift time so the first observation occurs at t=0 for numerical stability
    t_rel = t - t.min()

    df.loc[i, "total_time"] = float(t_rel.max() - t_rel.min())  # overall time baseline
    df.loc[i, "n_obs"] = int(lc.shape[0])                       # total number of observations

    df.loc[i, "median_flux"] = float(np.median(f))              # typical brightness (robust)
    df.loc[i, "mean_flux"]   = float(np.mean(f))                # average brightness
    df.loc[i, "std_flux"]    = float(np.std(f))                 # overall variability
    df.loc[i, "min_flux"]    = float(np.min(f))                 # dimmest point
    df.loc[i, "max_flux"]    = float(np.max(f))                 # brightest point
    df.loc[i, "range_flux"]  = float(np.max(f) - np.min(f))     # simple variability range

    df.loc[i, "median_err"] = float(np.median(e))               # typical measurement noise
    snr = np.abs(f) / (e + 1e-8)                                # SNR per observation
    df.loc[i, "median_snr"] = float(np.median(snr))             # typical detection quality
    df.loc[i, "max_snr"]    = float(np.max(snr))                # best detection quality
    df.loc[i, "neg_flux_frac"] = float(np.mean(f < 0))          # how often flux is negative

    present = 0
    total_obs = 0

    for band in filters:
        sub = lc[lc["Filter"] == band] # only observations in this band
        n = int(sub.shape[0])

        df.loc[i, f"n_obs_{band}"] = n
        total_obs += n

        # If the band is missing entirely, skip the rest
        if n == 0:
            continue
        present += 1

        tb = sub["Time (MJD)"].to_numpy()
        fb = sub["Flux"].to_numpy()
        eb = sub["Flux_err"].to_numpy()

        tb_rel = tb - tb.min()

        # Band time span
        df.loc[i, f"total_time_{band}"] = float(tb_rel.max() - tb_rel.min())

        # Band flux distribution
        df.loc[i, f"median_flux_{band}"] = float(np.median(fb))
        df.loc[i, f"std_flux_{band}"] = float(np.std(fb))

        # Band amplitude proxy (peak relative to median baseline)
        df.loc[i, f"amp_{band}"] = float(np.max(fb) - np.median(fb))

        # Band uncertainty + SNR
        df.loc[i, f"median_err_{band}"] = float(np.median(eb))
        snr_b = np.abs(fb) / (eb + 1e-8)
        df.loc[i, f"median_snr_{band}"] = float(np.median(snr_b))
        df.loc[i, f"max_snr_{band}"] = float(np.max(snr_b))

        # Band negative flux fraction
        df.loc[i, f"neg_flux_frac_{band}"] = float(np.mean(fb < 0))

    # Final band coverage summaries
    df.loc[i, "n_filters_present"] = int(present)
    df.loc[i, "total_obs"] = int(total_obs)

# %%
y = df['target']
X = df.drop(columns=['object_id', 'split', 'target'])
X
# Out:
#            Z    EBV  total_time  n_obs  median_flux  mean_flux  std_flux  \
# 0     3.0490  0.110   1254.2719   65.0    -0.367840   0.928483  4.766352
# 1     0.4324  0.058   2362.1560  167.0     0.094237   0.388622  1.367368
# 2     0.4673  0.577   1206.0218   35.0     1.076724   1.691347  2.602937
# 3     0.6946  0.012   2858.4129  798.0     0.327391   0.375366  0.859220
# 4     0.4161  0.058   2202.3065  129.0     0.308845   0.233832  1.142101
# ...      ...    ...         ...    ...          ...        ...       ...
# 3038  0.8898  0.042   2582.0800  148.0     0.328642   0.459678  0.999605
# 3039  0.9598  0.042   2916.1706  138.0     0.400943   0.374945  1.448300
# 3040  0.1543  0.024   1936.1637  172.0     0.104000   0.376307  1.070895
# 3041  1.1520  0.019   2699.8022  161.0     0.562826   0.352351  1.075207
# 3042  0.5595  0.034   1871.2077  167.0    -0.025445   0.275697  1.080632
#
#       min_flux   max_flux  range_flux  ...  total_time_y  median_flux_y  \
# 0    -2.756285  25.047343   27.803628  ...     1241.0691      -1.424537
# 1    -1.747082  11.375499   13.122581  ...     2362.1560       0.094237
# 2    -6.400816   6.617915   13.018732  ...      767.8628       0.032667
# 3    -7.641818   5.353821   12.995639  ...     2841.2281       0.523353
# 4    -3.060399   5.384463    8.444862  ...     1809.1164       0.826709
# ...        ...        ...         ...  ...           ...            ...
# 3038 -1.419681   6.428462    7.848143  ...     2392.4960       0.758492
# 3039 -5.330229   7.369065   12.699294  ...     2563.4588       0.363133
# 3040 -2.773028   5.085714    7.858741  ...     1919.4185      -0.031903
# 3041 -2.895248   2.871105    5.766353  ...     2635.9214       0.300762
# 3042 -2.768392   4.432613    7.201005  ...     1835.7234       0.372497
#
#       std_flux_y      amp_y  median_err_y  median_snr_y  max_snr_y  \
# 0       2.463050   7.290787      1.111663      1.344504   3.762247
# 1       2.457391  11.281263      1.300994      0.576262  14.659265
# 2       6.433483   6.433483      1.121800      5.735005   5.770355
# 3       1.798179   4.830468      1.079121      0.888426   3.630331
# 4       1.642351   1.543811      0.981047      1.312869   2.640597
# ...          ...        ...           ...           ...        ...
# 3038    1.853276   5.669970      1.135060      0.997986   2.542929
# 3039    1.773719   2.076330      1.336029      0.498384   2.478262
# 3040    1.798593   5.117617      1.198319      0.698936   4.619904
# 3041    1.446578   2.512944      1.378667      0.673259   2.712396
# 3042    1.642016   4.060116      1.139062      0.934261   4.311639
#
#       neg_flux_frac_y  n_filters_present  total_obs
# 0            0.545455                  6         65
# 1            0.482759                  6        167
# 2            0.500000                  6         35
# 3            0.365217                  6        798
# 4            0.285714                  6        129
# ...               ...                ...        ...
# 3038         0.375000                  6        148
# 3039         0.333333                  6        138
# 3040         0.548387                  6        172
# 3041         0.407407                  6        161
# 3042         0.433333                  6        167
#
# [3043 rows x 70 columns]

# %%
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=6
)

# %%
neg = (y_train == 0).sum()
pos = (y_train == 1).sum()
neg / pos # This dataset is heavily imbalanced, this ratio is for 'scale_pos_weight'
# Out:
# np.float64(19.627118644067796)

# %% [markdown]
# ## Hyperparameter tuning using Optuna
#
# Use Optuna to search for XGBoost hyperparameters that maximize F1 score.

# %%
import optuna
import numpy as np
from xgboost import XGBClassifier
from sklearn.metrics import f1_score

def objective(trial):
    params = {
        "objective": "binary:logistic",
        "eval_metric": "logloss",

        "n_estimators": trial.suggest_int("n_estimators", 300, 2000),
        "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.2, log=True),
        "max_depth": trial.suggest_int("max_depth", 2, 8),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 20),

        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.5, 1.0),

        "gamma": trial.suggest_float("gamma", 0.0, 5.0),

        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 10.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.1, 10.0),

        "scale_pos_weight": 19.6,

        "random_state": 42,
        "n_jobs": -1
    }

    model = XGBClassifier(**params)

    model.fit(X_train, y_train)

    probs = model.predict_proba(X_val)[:,1]

    ths = np.linspace(0.01, 0.99, 200)
    f1s = [f1_score(y_val, probs > t) for t in ths]

    return float(np.max(f1s))


study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=200)

print("\nBest F1:", study.best_value)
print("\nBest params:")
for k, v in study.best_params.items():
    print(f"{k}: {v}")
# Out:
# [I 2026-01-21 23:37:08,984] A new study created in memory with name: no-name-84d0c0be-22be-475c-91f7-5b9a70e5a255
# [I 2026-01-21 23:37:13,087] Trial 0 finished with value: 0.5970149253731343 and parameters: {'n_estimators': 1421, 'learning_rate': 0.006155384819269862, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.5644363241544073, 'colsample_bytree': 0.8816898009535024, 'colsample_bylevel': 0.9655292265593902, 'gamma': 0.8331651837526838, 'reg_alpha': 3.7237450041551168, 'reg_lambda': 3.311483869157942}. Best is trial 0 with value: 0.5970149253731343.
# [I 2026-01-21 23:37:15,352] Trial 1 finished with value: 0.6101694915254238 and parameters: {'n_estimators': 705, 'learning_rate': 0.02065035047243489, 'max_depth': 7, 'min_child_weight': 6, 'subsample': 0.6553728904188139, 'colsample_bytree': 0.8474071140108304, 'colsample_bylevel': 0.778116821044897, 'gamma': 1.7814850341642008, 'reg_alpha': 1.9308771851879347, 'reg_lambda': 4.951368122527224}. Best is trial 1 with value: 0.6101694915254238.
# [I 2026-01-21 23:37:17,413] Trial 2 finished with value: 0.5757575757575758 and parameters: {'n_estimators': 1680, 'learning_rate': 0.009733878669632181, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 0.877588010428682, 'colsample_bytree': 0.7805104424730308, 'colsample_bylevel': 0.9906415255600375, 'gamma': 3.537679465549419, 'reg_alpha': 6.651944886389003, 'reg_lambda': 9.706829410579088}. Best is trial 1 with value: 0.6101694915254238.
# [I 2026-01-21 23:37:19,259] Trial 3 finished with value: 0.59375 and parameters: {'n_estimators': 1602, 'learning_rate': 0.04638124000656093, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.68500421469848, 'colsample_bytree': 0.7428766744553037, 'colsample_bylevel': 0.686653331360132, 'gamma': 4.260412292611165, 'reg_alpha': 2.7940897975288284, 'reg_lambda': 9.572857372486142}. Best is trial 1 with value: 0.6101694915254238.
# [I 2026-01-21 23:37:21,079] Trial 4 finished with value: 0.6122448979591837 and parameters: {'n_estimators': 600, 'learning_rate': 0.005022173207861974, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.6842067910216458, 'colsample_bytree': 0.7845154390073529, 'colsample_bylevel': 0.5216233969246727, 'gamma': 4.95620670402351, 'reg_alpha': 8.452245184717068, 'reg_lambda': 9.823219062529397}. Best is trial 4 with value: 0.6122448979591837.
# [I 2026-01-21 23:37:21,997] Trial 5 finished with value: 0.5294117647058824 and parameters: {'n_estimators': 530, 'learning_rate': 0.08826830873319236, 'max_depth': 2, 'min_child_weight': 12, 'subsample': 0.5053859356351862, 'colsample_bytree': 0.9057120033786429, 'colsample_bylevel': 0.7585358501865207, 'gamma': 1.2490900232334357, 'reg_alpha': 4.053259367379466, 'reg_lambda': 5.428267940278234}. Best is trial 4 with value: 0.6122448979591837.
# [I 2026-01-21 23:37:22,985] Trial 6 finished with value: 0.46153846153846156 and parameters: {'n_estimators': 448, 'learning_rate': 0.006481009252341155, 'max_depth': 2, 'min_child_weight': 3, 'subsample': 0.9168585131918547, 'colsample_bytree': 0.5377501084448184, 'colsample_bylevel': 0.5955410387554774, 'gamma': 0.5659555082248213, 'reg_alpha': 4.4495162623727404, 'reg_lambda': 4.086313954681984}. Best is trial 4 with value: 0.6122448979591837.
# [I 2026-01-21 23:37:24,128] Trial 7 finished with value: 0.5538461538461539 and parameters: {'n_estimators': 863, 'learning_rate': 0.012766611265983453, 'max_depth': 2, 'min_child_weight': 8, 'subsample': 0.7344519517361823, 'colsample_bytree': 0.508189152740476, 'colsample_bylevel': 0.7072992255962154, 'gamma': 1.6370345811562421, 'reg_alpha': 5.236587197368525, 'reg_lambda': 5.503935326248054}. Best is trial 4 with value: 0.6122448979591837.
# [I 2026-01-21 23:37:25,689] Trial 8 finished with value: 0.68 and parameters: {'n_estimators': 705, 'learning_rate': 0.02684090039583841, 'max_depth': 7, 'min_child_weight': 13, 'subsample': 0.9984813411373075, 'colsample_bytree': 0.6381206849444303, 'colsample_bylevel': 0.5948390505846075, 'gamma': 0.8989580332065827, 'reg_alpha': 7.657179026083067, 'reg_lambda': 2.1264844284807065}. Best is trial 8 with value: 0.68.
# [I 2026-01-21 23:37:27,238] Trial 9 finished with value: 0.5818181818181818 and parameters: {'n_estimators': 1931, 'learning_rate': 0.05188883065022061, 'max_depth': 2, 'min_child_weight': 11, 'subsample': 0.8384192884619204, 'colsample_bytree': 0.5784616067218884, 'colsample_bylevel': 0.7959285963624172, 'gamma': 4.450282579086387, 'reg_alpha': 2.0996942897885607, 'reg_lambda': 2.3646484246337254}. Best is trial 8 with value: 0.68.
# [I 2026-01-21 23:37:28,344] Trial 10 finished with value: 0.5925925925925926 and parameters: {'n_estimators': 1063, 'learning_rate': 0.16000053817545254, 'max_depth': 8, 'min_child_weight': 18, 'subsample': 0.9899811916271513, 'colsample_bytree': 0.6289596691431201, 'colsample_bylevel': 0.5135245664766079, 'gamma': 0.06971692233621285, 'reg_alpha': 9.584923907715119, 'reg_lambda': 0.46396427277099783}. Best is trial 8 with value: 0.68.
# [I 2026-01-21 23:37
 'max_depth': 5, 'min_child_weight': 8, 'subsample': 0.9200756833391162, 'colsample_bytree': 0.9512813291303958, 'colsample_bylevel': 0.9149856622172867, 'gamma': 2.37902321444068, 'reg_alpha': 6.26887518304526, 'reg_lambda': 4.589108276038976}. Best is trial 29 with value: 0.7058823529411765.
# [I 2026-01-21 23:39:05,700] Trial 51 finished with value: 0.6909090909090909 and parameters: {'n_estimators': 1735, 'learning_rate': 0.008149589572553979, 'max_depth': 5, 'min_child_weight': 12, 'subsample': 0.9445107325108298, 'colsample_bytree': 0.9911056770658762, 'colsample_bylevel': 0.9453992249366536, 'gamma': 1.059265314699478, 'reg_alpha': 6.70922028813794, 'reg_lambda': 2.984631418357017}. Best is trial 29 with value: 0.7058823529411765.
# [I 2026-01-21 23:39:09,834] Trial 52 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 1699, 'learning_rate': 0.007211536215717125, 'max_depth': 5, 'min_child_weight': 11, 'subsample': 0.9463905058961489, 'colsample_bytree': 0.9980086116168525, 'colsample_bylevel': 0.9263963960327282, 'gamma': 0.23061364711508647, 'reg_alpha': 7.548833139179143, 'reg_lambda': 3.6994642821621113}. Best is trial 29 with value: 0.7058823529411765.
# [I 2026-01-21 23:39:12,855] Trial 53 finished with value: 0.6792452830188679 and parameters: {'n_estimators': 1489, 'learning_rate': 0.005775131202170407, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.9862027867515758, 'colsample_bytree': 0.9756697927136686, 'colsample_bylevel': 0.8791388704912183, 'gamma': 0.13034846492894026, 'reg_alpha': 7.523362277478869, 'reg_lambda': 2.6058960529784723}. Best is trial 29 with value: 0.7058823529411765.
# [I 2026-01-21 23:39:16,969] Trial 54 finished with value: 0.7169811320754716 and parameters: {'n_estimators': 1849, 'learning_rate': 0.006703801317360125, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9988536995847652, 'colsample_bytree': 0.9459122813644291, 'colsample_bylevel': 0.9804213162875464, 'gamma': 0.3149523123384763, 'reg_alpha': 7.801690403923806, 'reg_lambda': 3.6000791072635296}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:21,319] Trial 55 finished with value: 0.6909090909090909 and parameters: {'n_estimators': 1990, 'learning_rate': 0.006925326718940104, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9959945982245803, 'colsample_bytree': 0.94853097648119, 'colsample_bylevel': 0.9828468937674381, 'gamma': 0.15094051336575942, 'reg_alpha': 8.392149477084168, 'reg_lambda': 3.600863715877802}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:25,211] Trial 56 finished with value: 0.6785714285714286 and parameters: {'n_estimators': 1843, 'learning_rate': 0.008819457518438533, 'max_depth': 5, 'min_child_weight': 15, 'subsample': 0.9298104421534635, 'colsample_bytree': 0.9780639900420324, 'colsample_bylevel': 0.9995343170264521, 'gamma': 0.5936269319538876, 'reg_alpha': 7.963841318920546, 'reg_lambda': 2.0481661185316735}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:28,297] Trial 57 finished with value: 0.6551724137931034 and parameters: {'n_estimators': 1702, 'learning_rate': 0.007167956431143228, 'max_depth': 4, 'min_child_weight': 11, 'subsample': 0.8049145714572354, 'colsample_bytree': 0.9170751168136131, 'colsample_bylevel': 0.9198768434631365, 'gamma': 0.22906327515364727, 'reg_alpha': 9.043955815437712, 'reg_lambda': 3.82501780012247}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:32,880] Trial 58 finished with value: 0.6440677966101694 and parameters: {'n_estimators': 1887, 'learning_rate': 0.0058168058727946954, 'max_depth': 6, 'min_child_weight': 14, 'subsample': 0.8652561681696931, 'colsample_bytree': 0.9623066532425533, 'colsample_bylevel': 0.9533559408758282, 'gamma': 0.6253972429312584, 'reg_alpha': 7.254256175739772, 'reg_lambda': 4.283796748631806}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:35,750] Trial 59 finished with value: 0.6545454545454545 and parameters: {'n_estimators': 1591, 'learning_rate': 0.01009761681686325, 'max_depth': 5, 'min_child_weight': 17, 'subsample': 0.9435355091490091, 'colsample_bytree': 0.9999144184540565, 'colsample_bylevel': 0.9721538896225285, 'gamma': 0.9227169679886527, 'reg_alpha': 7.6980872862683585, 'reg_lambda': 3.2514237277709643}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:38,328] Trial 60 finished with value: 0.7058823529411765 and parameters: {'n_estimators': 1799, 'learning_rate': 0.013838275822847742, 'max_depth': 5, 'min_child_weight': 11, 'subsample': 0.9990220841114743, 'colsample_bytree': 0.9373846090135496, 'colsample_bylevel': 0.8983413601177578, 'gamma': 0.4033983960202646, 'reg_alpha': 8.193908166232827, 'reg_lambda': 1.2882016972851642}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:41,400] Trial 61 finished with value: 0.7058823529411765 and parameters: {'n_estimators': 1792, 'learning_rate': 0.00889650307984008, 'max_depth': 5, 'min_child_weight': 11, 'subsample': 0.9997522763692155, 'colsample_bytree': 0.889014762483929, 'colsample_bylevel': 0.8975377091870627, 'gamma': 0.41568693995761385, 'reg_alpha': 8.3709457061593, 'reg_lambda': 1.2591228215028423}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:43,848] Trial 62 finished with value: 0.68 and parameters: {'n_estimators': 1770, 'learning_rate': 0.013982382677881136, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9985551238591726, 'colsample_bytree': 0.8875928458323694, 'colsample_bylevel': 0.8317969239617644, 'gamma': 0.4327039396778347, 'reg_alpha': 8.229779663215758, 'reg_lambda': 1.0142852464432563}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:46,542] Trial 63 finished with value: 0.6923076923076923 and parameters: {'n_estimators': 1882, 'learning_rate': 0.01199006648360432, 'max_depth': 5, 'min_child_weight': 10, 'subsample': 0.9765147529540523, 'colsample_bytree': 0.939002273867226, 'colsample_bylevel': 0.8932793873293166, 'gamma': 0.7074941551976699, 'reg_alpha': 9.182484033909935, 'reg_lambda': 1.3262365215435366}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:49,319] Trial 64 finished with value: 0.6792452830188679 and parameters: {'n_estimators': 1975, 'learning_rate': 0.008762031888941708, 'max_depth': 4, 'min_child_weight': 13, 'subsample': 0.9639294864874821, 'colsample_bytree': 0.8569960737266393, 'colsample_bylevel': 0.8630464118713107, 'gamma': 0.896139417148287, 'reg_alpha': 9.831263976221685, 'reg_lambda': 1.6212374493058346}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:51,936] Trial 65 finished with value: 0.6792452830188679 and parameters: {'n_estimators': 1777, 'learning_rate': 0.011356024877489396, 'max_depth': 6, 'min_child_weight': 15, 'subsample': 0.9981027375694969, 'colsample_bytree': 0.9074508142384821, 'colsample_bylevel': 0.8700656188721622, 'gamma': 1.2722181017555252, 'reg_alpha': 8.425190556274822, 'reg_lambda': 0.5667367537207566}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:53,424] Trial 66 finished with value: 0.6792452830188679 and parameters: {'n_estimators': 1666, 'learning_rate': 0.11608240149549393, 'max_depth': 5, 'min_child_weight': 11, 'subsample': 0.9799610268226842, 'colsample_bytree': 0.841791481249043, 'colsample_bylevel': 0.904325058494994, 'gamma': 0.5184874712884228, 'reg_alpha': 8.745499173962685, 'reg_lambda': 2.3313075536813397}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:39:57,396] Trial 67 finished with value: 0.6909090909090909 and parameters: {'n_estimators': 1923, 'learning_rate': 0.008969191192214506, 'max_depth': 5, 'min_child_weight': 12, 'subsample': 0.9619824997326838, 'colsample_bytree': 0.878427101033137, 'colsample_bylevel': 0.9498261078105954, 'gamma': 0.036417193740538534, 'reg_alpha': 7.899592725556317, 'reg_lambda': 2.6871421571614733}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:40:00,508] Trial 68 finished with value: 0.5846153846153846 and parameters: {'n_estimators': 1848, 'learning_rate': 0.01722628746323227, 'max_depth': 6, 'min_child_weight': 14, 'subsample': 0.6304818953605562, 'colsample_bytree': 0.8231396949290596, 'colsample_bylevel': 0.9685333721306044, 'gamma': 0.33792748185300103, 'reg_alpha': 7.309973996143973, 'reg_lambda': 2.0884344049533157}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:40:02,661] Trial 69 finished with value: 0.6551724137931034 and parameters: {'n_estimators': 1117, 'learning_rate': 0.010314854213132683, 'max_depth': 4, 'min_child_weight': 9, 'subsample': 0.9833872492373534, 'colsample_bytree': 0.9204943012529256, 'colsample_bylevel': 0.9198479716725382, 'gamma': 0.701153653078493, 'reg_alpha': 6.833575223826893, 'reg_lambda': 0.6972172586459646}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:40:04,253] Trial 70 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 1549, 'learning_rate': 0.058478982013479876, 'max_depth': 5, 'min_child_weight': 10, 'subsample': 0.9303100224214893, 'colsample_bytree': 0.9429486609407564, 'colsample_bylevel': 0.93785157244092, 'gamma': 0.9956463641047053, 'reg_alpha': 7.755646771532612, 'reg_lambda': 1.5037218504717884}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:40
finished with value: 0.6909090909090909 and parameters: {'n_estimators': 1634, 'learning_rate': 0.005705229595486638, 'max_depth': 5, 'min_child_weight': 12, 'subsample': 0.9358224317501181, 'colsample_bytree': 0.966195271740472, 'colsample_bylevel': 0.893554440087437, 'gamma': 1.1759715861071693, 'reg_alpha': 7.276282348614725, 'reg_lambda': 3.7262507706067014}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:40:47,659] Trial 82 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 1811, 'learning_rate': 0.006235746403234141, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9698431152701369, 'colsample_bytree': 0.5020305453160856, 'colsample_bylevel': 0.872430639995642, 'gamma': 1.2563064622094944, 'reg_alpha': 7.786696375955909, 'reg_lambda': 4.079807514768187}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:40:52,185] Trial 83 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 1692, 'learning_rate': 0.007107920150348239, 'max_depth': 5, 'min_child_weight': 11, 'subsample': 0.9484384430456729, 'colsample_bytree': 0.9715715036115579, 'colsample_bylevel': 0.9586436773355113, 'gamma': 0.9387182026801539, 'reg_alpha': 7.066933059186385, 'reg_lambda': 4.300461718361557}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:40:55,212] Trial 84 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 1445, 'learning_rate': 0.010811469970739986, 'max_depth': 5, 'min_child_weight': 12, 'subsample': 0.9092881077293946, 'colsample_bytree': 0.9996767894829777, 'colsample_bylevel': 0.8400185364567186, 'gamma': 1.8010818206397015, 'reg_alpha': 8.186094627692448, 'reg_lambda': 2.917040188996222}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:40:59,668] Trial 85 finished with value: 0.6909090909090909 and parameters: {'n_estimators': 1656, 'learning_rate': 0.009727928994951202, 'max_depth': 6, 'min_child_weight': 14, 'subsample': 0.986305550530368, 'colsample_bytree': 0.9888493100199277, 'colsample_bylevel': 0.7865665018752965, 'gamma': 0.3995770132388409, 'reg_alpha': 8.789091722557194, 'reg_lambda': 9.99924024339235}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:41:01,656] Trial 86 finished with value: 0.6792452830188679 and parameters: {'n_estimators': 1296, 'learning_rate': 0.03994265368496522, 'max_depth': 5, 'min_child_weight': 9, 'subsample': 0.9261316714700638, 'colsample_bytree': 0.9533581273492071, 'colsample_bylevel': 0.9354324727497466, 'gamma': 0.8219093174518336, 'reg_alpha': 6.471677368617413, 'reg_lambda': 3.280474821417366}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:41:05,673] Trial 87 finished with value: 0.6415094339622641 and parameters: {'n_estimators': 1734, 'learning_rate': 0.00859967674854238, 'max_depth': 5, 'min_child_weight': 12, 'subsample': 0.8800673456707147, 'colsample_bytree': 0.9330375816254177, 'colsample_bylevel': 0.8886216691552834, 'gamma': 1.0549641724936067, 'reg_alpha': 7.517014935290177, 'reg_lambda': 1.1870296308412045}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:41:08,263] Trial 88 finished with value: 0.6792452830188679 and parameters: {'n_estimators': 1511, 'learning_rate': 0.005386599053610019, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.9683542418080142, 'colsample_bytree': 0.5252362814271925, 'colsample_bylevel': 0.9721249522542171, 'gamma': 0.3247609911279776, 'reg_alpha': 5.616853069592112, 'reg_lambda': 3.923402467935898}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:41:11,174] Trial 89 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 1385, 'learning_rate': 0.0070899513902977955, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9417031707980765, 'colsample_bytree': 0.8708914746835967, 'colsample_bylevel': 0.7367774953176849, 'gamma': 0.555513238783125, 'reg_alpha': 7.964143522585901, 'reg_lambda': 4.766603795275576}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:41:16,041] Trial 90 finished with value: 0.6440677966101694 and parameters: {'n_estimators': 1872, 'learning_rate': 0.006277050528794671, 'max_depth': 6, 'min_child_weight': 11, 'subsample': 0.8254318863806426, 'colsample_bytree': 0.9829269436648389, 'colsample_bylevel': 0.9999538566022496, 'gamma': 0.7057723522780881, 'reg_alpha': 6.739695222467338, 'reg_lambda': 5.268073322481715}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:41:19,501] Trial 91 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 1591, 'learning_rate': 0.013070101480455893, 'max_depth': 5, 'min_child_weight': 11, 'subsample': 0.988486922524821, 'colsample_bytree': 0.956739748236121, 'colsample_bylevel': 0.9417822278530772, 'gamma': 0.09028984202937071, 'reg_alpha': 7.409885808662054, 'reg_lambda': 1.9015955114221823}. Best is trial 54 with value: 0.7169811320754716.
# [I 2026-01-21 23:41
. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:42:02,684] Trial 102 finished with value: 0.6785714285714286 and parameters: {'n_estimators': 1678, 'learning_rate': 0.011360677733652468, 'max_depth': 5, 'min_child_weight': 12, 'subsample': 0.9390058073324912, 'colsample_bytree': 0.7608738436951901, 'colsample_bylevel': 0.9124382003271214, 'gamma': 0.2075727215889186, 'reg_alpha': 2.2814070295105666, 'reg_lambda': 3.001132949037644}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:42:07,193] Trial 103 finished with value: 0.68 and parameters: {'n_estimators': 1837, 'learning_rate': 0.008225661599631055, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.9896266069019687, 'colsample_bytree': 0.9639474699303745, 'colsample_bylevel': 0.9269023556102507, 'gamma': 0.3286867914376978, 'reg_alpha': 7.63046052189124, 'reg_lambda': 3.3489693159731924}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:42:11,324] Trial 104 finished with value: 0.6909090909090909 and parameters: {'n_estimators': 1531, 'learning_rate': 0.006542502607603264, 'max_depth': 5, 'min_child_weight': 10, 'subsample': 0.9540449049987741, 'colsample_bytree': 0.9788937578480973, 'colsample_bylevel': 0.8766591909874384, 'gamma': 0.42366422154922456, 'reg_alpha': 8.249939915255723, 'reg_lambda': 3.134099122328896}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:42:14,634] Trial 105 finished with value: 0.6785714285714286 and parameters: {'n_estimators': 1616, 'learning_rate': 0.012262553323682144, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9667999891580862, 'colsample_bytree': 0.9063068833938183, 'colsample_bylevel': 0.9740405223869728, 'gamma': 0.7696993777551936, 'reg_alpha': 7.90605803657327, 'reg_lambda': 2.801419429605472}. Best is trial 101 with value: 0.7307692307692307.
# ...
# [I 2026-01-21 23:45:41,358] Trial 166 finished with value: 0.6923076923076923 and parameters: {'n_estimators': 1772, 'learning_rate': 0.008937254787640814, 'max_depth': 5, 'min_child_weight': 12, 'subsample': 0.9829350821304026, 'colsample_bytree': 0.9592247433866576, 'colsample_bylevel': 0.9373662946578669, 'gamma': 0.9788034596002044, 'reg_alpha': 5.839741512318602, 'reg_lambda': 0.9085922373908217}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:45:45,043] Trial 167 finished with value: 0.7058823529411765 and parameters: {'n_estimators': 1951, 'learning_rate': 0.011214038866669407, 'max_depth': 5, 'min_child_weight': 11, 'subsample': 0.9906031260504974, 'colsample_bytree': 0.9418234013633505, 'colsample_bylevel': 0.9890071757595693, 'gamma': 0.3084881333842306, 'reg_alpha': 6.144633473670902, 'reg_lambda': 2.2428974913052553}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:45:48,704] Trial 168 finished with value: 0.7169811320754716 and parameters: {'n_estimators': 1895, 'learning_rate': 0.012583799815680348, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9731208684818955, 'colsample_bytree': 0.9800735233595106, 'colsample_bylevel': 0.9810543911063957, 'gamma': 0.10788658578801245, 'reg_alpha': 7.889019531792875, 'reg_lambda': 1.3730179121788}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:45:51,831] Trial 169 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 1921, 'learning_rate': 0.013272148614308966, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9583777650815792, 'colsample_bytree': 0.5676292905699174, 'colsample_bylevel': 0.9761571052798789, 'gamma': 0.11965524154722917, 'reg_alpha': 7.9331592330363465, 'reg_lambda': 1.2806383118160602}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:45:54,933] Trial 170 finished with value: 0.6785714285714286 and parameters: {'n_estimators': 1872, 'learning_rate': 0.012482535159055815, 'max_depth': 4, 'min_child_weight': 15, 'subsample': 0.9693676752001891, 'colsample_bytree': 0.9669188337369437, 'colsample_bylevel': 0.9816055194692571, 'gamma': 0.2459223724848918, 'reg_alpha': 8.248801169184187, 'reg_lambda': 1.7980238012547838}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:45:58,786] Trial 171 finished with value: 0.7169811320754716 and parameters: {'n_estimators': 1835, 'learning_rate': 0.017055667753984656, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9762706527988105, 'colsample_bytree': 0.9804263817956963, 'colsample_bylevel': 0.9646743347797236, 'gamma': 0.10578599182876146, 'reg_alpha': 7.203846461944967, 'reg_lambda': 1.4354387714998538}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:46:01,977] Trial 172 finished with value: 0.6923076923076923 and parameters: {'n_estimators': 1826, 'learning_rate': 0.018517096129493045, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.
 'max_depth': 5, 'min_child_weight': 12, 'subsample': 0.9997952063515969, 'colsample_bytree': 0.9744233623395608, 'colsample_bylevel': 0.99122633548244, 'gamma': 0.10213382113051139, 'reg_alpha': 8.344403338384774, 'reg_lambda': 0.6589876165643636}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:46:36,193] Trial 184 finished with value: 0.6909090909090909 and parameters: {'n_estimators': 1713, 'learning_rate': 0.013973423659412572, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9890516886420738, 'colsample_bytree': 0.875382556125818, 'colsample_bylevel': 0.9669707892234565, 'gamma': 0.37097068115203286, 'reg_alpha': 7.479015863880169, 'reg_lambda': 1.2157751410989324}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:46:39,158] Trial 185 finished with value: 0.7058823529411765 and parameters: {'n_estimators': 1674, 'learning_rate': 0.016086923114760288, 'max_depth': 5, 'min_child_weight': 11, 'subsample': 0.972705894425658, 'colsample_bytree': 0.9463067245303551, 'colsample_bylevel': 0.9358605447202196, 'gamma': 0.22744341328245327, 'reg_alpha': 7.817662444630178, 'reg_lambda': 0.8489604293365725}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:46:42,055] Trial 186 finished with value: 0.6909090909090909 and parameters: {'n_estimators': 1781, 'learning_rate': 0.019108414493888854, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.96158801805742, 'colsample_bytree': 0.9641431388280877, 'colsample_bylevel': 0.9986621868345774, 'gamma': 0.11455460943559563, 'reg_alpha': 9.513302186290176, 'reg_lambda': 0.3187598401069707}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:46:44,433] Trial 187 finished with value: 0.6923076923076923 and parameters: {'n_estimators': 807, 'learning_rate': 0.013707666235788942, 'max_depth': 5, 'min_child_weight': 14, 'subsample': 0.9884094608861037, 'colsample_bytree': 0.9781063813243347, 'colsample_bylevel': 0.9799342090147518, 'gamma': 0.3232797016954963, 'reg_alpha': 7.617592378933639, 'reg_lambda': 3.036371739686305}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:46:47,097] Trial 188 finished with value: 0.68 and parameters: {'n_estimators': 1507, 'learning_rate': 0.014975275751794838, 'max_depth': 5, 'min_child_weight': 11, 'subsample': 0.9758357131751514, 'colsample_bytree': 0.9584017980068205, 'colsample_bylevel': 0.7703244661958375, 'gamma': 0.42303820896360983, 'reg_alpha': 7.965536984826379, 'reg_lambda': 1.1092961114577928}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:46:49,727] Trial 189 finished with value: 0.6923076923076923 and parameters: {'n_estimators': 1749, 'learning_rate': 0.019809966794134323, 'max_depth': 5, 'min_child_weight': 10, 'subsample': 0.9895089172072155, 'colsample_bytree': 0.9362422462161338, 'colsample_bylevel': 0.9288357305176645, 'gamma': 0.09998400173474367, 'reg_alpha': 7.3359825450568925, 'reg_lambda': 0.5338038225126253}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:46:52,271] Trial 190 finished with value: 0.7058823529411765 and parameters: {'n_estimators': 1445, 'learning_rate': 0.017559562051029626, 'max_depth': 5, 'min_child_weight': 12, 'subsample': 0.9797390393947467, 'colsample_bytree': 0.9195040809293705, 'colsample_bylevel': 0.8991031836634976, 'gamma': 0.2022744689465875, 'reg_alpha': 8.232254077404772, 'reg_lambda': 1.3080106207841822}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:46:54,762] Trial 191 finished with value: 0.7037037037037037 and parameters: {'n_estimators': 1812, 'learning_rate': 0.022028140688825817, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9943670341405487, 'colsample_bytree': 0.9803885904269116, 'colsample_bylevel': 0.9854765960348159, 'gamma': 0.41559688555462887, 'reg_alpha': 7.678556965498905, 'reg_lambda': 1.4613174073677666}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:46:56,578] Trial 192 finished with value: 0.6909090909090909 and parameters: {'n_estimators': 1814, 'learning_rate': 0.0878689942773889, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9921986543108456, 'colsample_bytree': 0.9675669549297455, 'colsample_bylevel': 0.9679734366876606, 'gamma': 0.2789633312070012, 'reg_alpha': 8.438406503859843, 'reg_lambda': 1.8323141280863056}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:47:00,529] Trial 193 finished with value: 0.68 and parameters: {'n_estimators': 1767, 'learning_rate': 0.01207982857458481, 'max_depth': 5, 'min_child_weight': 12, 'subsample': 0.9843199111857989, 'colsample_bytree': 0.8259964243076542, 'colsample_bylevel': 0.9850450371319994, 'gamma': 0.010807222761641533, 'reg_alpha': 7.225351827606827, 'reg_lambda': 1.3944990794150465}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:47:04,514] Trial 194 finished with value: 0.6923076923076923 and parameters: {'n_estimators': 1847, 'learning_rate': 0.0077866371860695754, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9983029857092364, 'colsample_bytree': 0.9910033105255778, 'colsample_bylevel': 0.9529771893496629, 'gamma': 0.4644782335524211, 'reg_alpha': 7.99680451236108, 'reg_lambda': 1.018048076347358}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:47:08,128] Trial 195 finished with value: 0.6792452830188679 and parameters: {'n_estimators': 1894, 'learning_rate': 0.013316189324348384, 'max_depth': 5, 'min_child_weight': 12, 'subsample': 0.9707525533572882, 'colsample_bytree': 0.9997453951728547, 'colsample_bylevel': 0.9764641267386898, 'gamma': 0.1678577921315186, 'reg_alpha': 7.488703457465186, 'reg_lambda': 1.673507271128709}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:47:10,790] Trial 196 finished with value: 0.6923076923076923 and parameters: {'n_estimators': 1693, 'learning_rate': 0.016252855022434818, 'max_depth': 5, 'min_child_weight': 14, 'subsample': 0.9992023483677892, 'colsample_bytree': 0.9751464997271994, 'colsample_bylevel': 0.9618544309551202, 'gamma': 0.33028819579485413, 'reg_alpha': 7.781814940406876, 'reg_lambda': 0.7630530540441313}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:47:14,284] Trial 197 finished with value: 0.6909090909090909 and parameters: {'n_estimators': 1916, 'learning_rate': 0.011590268539473255, 'max_depth': 5, 'min_child_weight': 11, 'subsample': 0.982896775725467, 'colsample_bytree': 0.9840722740675952, 'colsample_bylevel': 0.991597334668978, 'gamma': 0.580514446570036, 'reg_alpha': 7.1229911606412895, 'reg_lambda': 3.297054270467154}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:47:17,659] Trial 198 finished with value: 0.7058823529411765 and parameters: {'n_estimators': 1792, 'learning_rate': 0.012923058926212387, 'max_depth': 5, 'min_child_weight': 13, 'subsample': 0.9612675103534934, 'colsample_bytree': 0.9488766874143538, 'colsample_bylevel': 0.910542335710903, 'gamma': 0.08647311202254558, 'reg_alpha': 8.80350093647672, 'reg_lambda': 2.018278076385279}. Best is trial 101 with value: 0.7307692307692307.
# [I 2026-01-21 23:47:21,600] Trial 199 finished with value: 0.6923076923076923 and parameters: {'n_estimators': 1958, 'learning_rate': 0.014440276094940226, 'max_depth': 5, 'min_child_weight': 12, 'subsample': 0.9898379775025379, 'colsample_bytree': 0.9617545997446932, 'colsample_bylevel': 0.9734952072784842, 'gamma': 0.2093636479272148, 'reg_alpha': 8.179620791764696, 'reg_lambda': 1.5551589864233775}. Best is trial 101 with value: 0.7307692307692307.
# Best F1: 0.7307692307692307
#
# Best params:
# n_estimators: 1556
# learning_rate: 0.011529285096593348
# max_depth: 5
# min_child_weight: 11
# subsample: 0.9904688515865391
# colsample_bytree: 0.9648603980227474
# colsample_bylevel: 0.9311605391986038
# gamma: 0.008019928262850695
# reg_alpha: 7.434848384560268
# reg_lambda: 1.9371612433399945

# %%
best_params = study.best_params

model = XGBClassifier(
    **best_params,
    objective="binary:logistic",
    eval_metric="logloss",
    scale_pos_weight=19.6,
    random_state=42,
    n_jobs=-1
)

model.fit(X_train, y_train)

probs = model.predict_proba(X_val)[:,1]

ths = np.linspace(0.01, 0.99, 300)
f1s = [f1_score(y_val, probs > t) for t in ths]
best_t = ths[np.argmax(f1s)]

print("Best threshold:", best_t)
# Out:
# Best threshold: 0.5147491638795987

# %%
from loader.test_loader import build_test

X_test, test_df = build_test()
probs = model.predict_proba(X_test)[:,1]
y_test_pred = (probs > best_t).astype(int)

submission = pd.DataFrame({
    "object_id": test_df["object_id"],
    "target": y_test_pred
})
submission.to_csv("submissions/XGB2.csv", index=False)
